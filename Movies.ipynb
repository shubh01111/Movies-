# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Copy of moviesData (1).csv')
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# 1. Display Top 10 Rows of The Dataset

# %%
df.head(10)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6  260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7  280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8  250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage      id  \
# 0                        http://www.avatarmovie.com/   19995
# 1       http://disney.go.com/disneypictures/pirates/     285
# 2        http://www.sonypictures.com/movies/spectre/  206647
# ...

# %% [markdown]
# 2. Check Last 10 Rows of The Dataset

# %%
df.tail(10)
# Out:
#       budget                                             genres  \
# 4793       0                      [{"id": 18, "name": "Drama"}]
# 4794       0  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
# 4795       0                      [{"id": 18, "name": "Drama"}]
# 4796    7000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 4797       0  [{"id": 10769, "name": "Foreign"}, {"id": 53, ...
# 4798  220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799    9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801       0                                                 []
# 4802       0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 4793                                                NaN  182291
# 4794                                                NaN  286939
# 4795                                                NaN  124606
# ...

# %% [markdown]
# 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
x=df.shape
print('Number of rows =',x[0])
print('Number of columns =',x[1])
# Out:
# Number of rows = 4803
# Number of columns = 20

# %% [markdown]
# 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns,
# Datatypes of Each Column And Memory Requirement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %% [markdown]
# 5. Check Missing Values In The Dataset

# %%
df.isnull().sum()
# Out:
# budget                  0
# genres                  0
# homepage                0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %% [markdown]
# 6. Drop All The Missing Values

# %%
df.dropna(subset='homepage',inplace=True)

# %%
df.dropna(subset='tagline',inplace=True)

# %% [markdown]
# 7. Check For Duplicate Data

# %%
df.duplicated().any()
# Out:
# False

# %% [markdown]
# 8. Get Overall Statistics About The DataFrame

# %%
df.describe(include='all')
# Out:
#               budget                         genres  \
# count   1.493000e+03                           1493
# unique           NaN                            555
# top              NaN  [{"id": 18, "name": "Drama"}]
# freq             NaN                             91
# mean    4.589534e+07                            NaN
# std     5.369219e+07                            NaN
# min     0.000000e+00                            NaN
# 25%     7.500000e+06                            NaN
# 50%     2.700000e+07                            NaN
# 75%     6.300000e+07                            NaN
# max     3.800000e+08                            NaN
#
#                                 homepage             id keywords  \
# count                               1493    1493.000000     1493
# unique                              1473            NaN     1414
# top     http://www.thehungergames.movie/            NaN       []
# freq                                   4            NaN       61
# ...

# %% [markdown]
# 9. Display Title of The Movie Having Runtime Greater Than or equal to 180 Minutes

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
df180=df[df['runtime']>=180.0]
df180['original_title']
# Out:
# 25                                            Titanic
# 298                           The Wolf of Wall Street
# 329     The Lord of the Rings: The Return of the King
# 690                                    The Green Mile
# 1333                                         Magnolia
# 1818                                 Schindler's List
# Name: original_title, dtype: object

# %% [markdown]
# 10. In Which Year There Was The Highest Average Voting?

# %%
df['release_date']=pd.to_datetime(df['release_date'])

# %%
df['Year']=df['release_date'].dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1493 entries, 0 to 4801
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                1493 non-null   int64
#  1   genres                1493 non-null   object
#  2   homepage              1493 non-null   object
#  3   id                    1493 non-null   int64
#  4   keywords              1493 non-null   object
#  5   original_language     1493 non-null   object
#  6   original_title        1493 non-null   object
#  7   overview              1493 non-null   object
#  8   popularity            1493 non-null   float64
#  9   production_companies  1493 non-null   object
#  10  production_countries  1493 non-null   object
#  11  release_date          1493 non-null   datetime64[ns]
#  12  revenue               1493 non-null   int64
#  13  runtime               1493 non-null   float64
# ...

# %%
df['Year']
# Out:
# 0       2009
# 1       2007
# 2       2015
# 3       2012
# 4       2012
#         ...
# 4773    1994
# 4781    2013
# 4791    2007
# 4796    2004
# 4801    2012
# Name: Year, Length: 1493, dtype: int64

# %%
df.loc[df['vote_average'].idxmax()]['Year']
# Out:
# 1972

# %% [markdown]
# 11. In Which Year There Was The Highest Average Revenue?

# %%
revdf=df.groupby('Year')['revenue'].mean()
revdf.sort_values().tail(1)
# Out:
# Year
# 1977    480418340.0
# Name: revenue, dtype: float64

# %% [markdown]
# 12. Find The Average Votecount For Each Production

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'Year'],
#       dtype='object')

# %%
df.groupby('production_companies')['vote_count'].mean()
# Out:
# production_companies
# []                                                                                                                                                                                                                                                                           19.902439
# [{"name": "1492 Pictures", "id": 436}, {"name": "Dune Entertainment", "id": 444}, {"name": "Fox 2000 Pictures", "id": 711}, {"name": "Sunswept Entertainment", "id": 5219}, {"name": "Dune Entertainment III", "id": 6332}, {"name": "TSG Entertainment", "id": 22213}]    1648.000000
# [{"name": "1492 Pictures", "id": 436}, {"name": "Warner Bros.", "id": 6194}, {"name": "Heyday Films", "id": 7364}]                                                                                                                                                         7006.000000
# ...

# %% [markdown]
# 13. Display Top 10 Lengthy Movies Title and Runtime

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'Year'],
#       dtype='object')

# %%
lengdf=df.sort_values(by='runtime',ascending=False).head(10)
lengdf[['original_title','runtime']]
# Out:
#                                          original_title  runtime
# 329       The Lord of the Rings: The Return of the King    201.0
# 1818                                   Schindler's List    195.0
# 25                                              Titanic    194.0
# 690                                      The Green Mile    189.0
# 1333                                           Magnolia    188.0
# 298                             The Wolf of Wall Street    180.0
# 330               The Lord of the Rings: The Two Towers    179.0
# 407                                      Meet Joe Black    178.0
# 262   The Lord of the Rings: The Fellowship of the Ring    178.0
# 3337                                      The Godfather    175.0

# %% [markdown]
# 14. Find Most Popular Movie Title (Highest Revenue)

# %%
df.loc[df['revenue'].idxmax()]['original_title']
# Out:
# 'Avatar'

# %% [markdown]
# 15. Count Number of Action Movies

# %%
len(df[df['genres'].str.contains('Action',case=False)])
# Out:
# 417

# %% [markdown]
# 16. How Many Films of Each Genre Were Made?

# %%
df['genres'].value_counts()
# Out:
# [{"id": 18, "name": "Drama"}]                                                                                                                                 91
# [{"id": 35, "name": "Comedy"}]                                                                                                                                74
# [{"id": 18, "name": "Drama"}, {"id": 10749, "name": "Romance"}]                                                                                               47
# [{"id": 35, "name": "Comedy"}, {"id": 10749, "name": "Romance"}]                                                                                              38
# [{"id": 35, "name": "Comedy"}, {"id": 18, "name": "Drama"}]                                                                                                   32
#                                                                                                                                                               ..
# ...
